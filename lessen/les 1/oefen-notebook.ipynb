# %% [markdown]
# # Test notebook
#
# Je kan een cell in een notebook editeren door er met de muis op te dubbelklikken, of het "potloodje" te selecteren als je over de cell glijdt.
# Dat is bijvoorbeeld heel handig om _tijdens de les_ je **eigen aantekeningen** te maken in de aangeleverde notebook.
#
# De opmaak in deze cell gebeurt volgens "[Markdown](https://en.wikipedia.org/wiki/Markdown)", een vereenvoudigde versie van [HTML](https://en.wikipedia.org/wiki/HTML) dat gebruikt wordt om webpagina's te coderen.
# Bovenaan de tekst van de cell zie je een _hoofding_ die start met een `hash tag`.
#
# Een hoofding van tweede orde gebruikt twee hash tags, zoals hieronder:
#
# ## Sub-titel
# De belangrijkste opmaakcodes staan op de hogervermelde [link](https://en.wikipedia.org/wiki/Markdown#Examples)
#
# Je kan een cell opbreken, door de "Split cell" kop bovenaan de cell.

# %% [markdown]
# <h1>Sectie gemaakt in HTML</h1>
# Een rijker alternatief dan Markdown is HTML (de &ldquo;programmeertaal&rdquo; van het World Wide Web), en je kan in deze cell zien hoe HTML gebruikt kan worden.
# Hieronder volgen een aantal voorbeelden van eenvoudige opmaak (waarvan je de encodering kan zien als je naar de editeermode van de cell gaat):
#
# Opsomming:
# <ul>
# <li>&eacute;&eacute;n.
# <li>twee.
# <li>drie.
# </ul>
#
# Genummerde opsomming:
# <ol>
# <li>&eacute;&eacute;n.
# <li>twee.
# <li>drie.
# </ol>
#
# Tekst kan je <b>vetjes</b> maken, of <em>benadrukken</em>, of <u>onderlijnen</u>.
#
# Figuren sluit je in op deze manier (als je het bestand met de figuur in dezelfde folder hebt staan als deze notebook):
#
# <div style="height: 5rem;">
#   <img height="100%" src="./prentje.svg" >
# </div>
#
# Als je een online figuur wil insluiten is de opmaak bijna dezelfde: je vervangt de locatie van het bestand hierboven door een URL naar de online figuur.
#
# <div style="height: 8rem;">
#   <img height="100%" src="https://u0011821.pages.gitlab.kuleuven.be/images/20231129-HermanBruyninckx-small.jpg">
# </div>

# %% [markdown]
# <h2>Gebruik van LaTeX formules</h2>
#
# Dit is de wet van Newton, in doorlopende tekst: $F = m a$.
# Let op: er moet een lege lijn staan boven deze paragraaf,
# anders wordt de LaTex formule niet gerendered.
#
# <p>Dat zie je hier: $F = m a$.
#
# Hier is een bekende formule van Einstein, weergegeven als een vergelijking op een aparte lijn, aangeduid door de twee dollartekens v&oacute;&oacute;r en na de formule:
# $$E = m c^2.$$
#
# Je kan LaTeX ook gebruiken voor uitgelijnde matrices, waarbij &ldquo;&amp;&rdquo; het uitlijnsymbool is, en een dubbele &ldquo;&bsol;&bsol;&rdquo; een nieuwe rij van de matrix aangeeft (dat zie je pas in editeer-mode, natuurlijk):
#
# \begin{aligned}
# M &= \sin^2(\alpha) + \cos^2(\alpha)
# \\
#   &= 1
# \end{aligned}

# %% [markdown]
# <h2>Rekenen met Python</h2>
# Als je de Python extensie heb geïnstalleerd, dan kan je ook beginnen rekenen, zoals met de Python cell hieronder.
# De code wordt uitgevoerd als je op het &#9655; symbooltje klikt, dat je vindt aan de linkerbovenkant van de cell.

# %%
import numpy as np
# Create two sample arrays
array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

# Perform element-wise addition
result = array1 + array2

# Print the result
print(result)
# Out:
# [5 7 9]

# %% [markdown]
# De volgende Python bibliotheken gebruiken we in dit vak:
# <a href="https://en.wikipedia.org/wiki/NumPy">numpy</a>,
# <a href="https://en.wikipedia.org/wiki/Scipy">scipy</a>,
# <a href="https://en.wikipedia.org/wiki/matplotlib">matplotlib</a>.

# %% [markdown]
# <h2>Extensies installeren</h2>
# VS Code laat toe om (redelijk) makkelijk de benodigde &ldquo;Extensions&rdquo; te installeren.
# Daarvoor open je de zijbalk waarin je de volgende rubrieken vindt: <em>Explorer</em>, <em>Search</em>, enz,
# en ook <em>Extensions</em>.
# Voor deze oefen-notebook heb je de volgende extensies nodig:
# <ul>
# <li>Jupyter
# <li>Jupyter Cell Tags
# <li>Jupyter Keymap
# <li>Jupyter Notebook Renderers
# <li>LaTeX
# <li>Pylance
# <li>Python
# <li>vscod all markdown
# </ul>
